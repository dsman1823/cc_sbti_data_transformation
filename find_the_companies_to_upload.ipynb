# %%
import pandas as pd 

from difflib import SequenceMatcher
from rapidfuzz import process, fuzz
from difflib import SequenceMatcher

# %%
# !ls ../cc/
# Out:
# companies.csv  countries.csv  industries.csv

# %%
sbti_df =  pd.read_excel('../target-dashboard.xlsx')
companies_df = pd.read_csv('../cc/companies.csv')         # <-- 
industries_df = pd.read_csv('../cc/industries.csv')       # <-- AppIndustries table from PRD DB
countries_df = pd.read_csv('../cc/countries.csv')         # <--

# %% [markdown]
# ## Ignore companies with removed targets

# %%
sbti_df[sbti_df['Status']=='Removed']['Company Name'].unique()
# Out:
# array(['3B-Fibreglass', 'ACCEDO BROADBAND AB', 'Accor S.A.',
#        'Ace & Tate Holding B.V.', 'Ace Technologies Co.,Ltd.', 'Acensi',
#        'Acerinox,S.A.', 'AÇO VERDE DO BRASIL.S.A',
#        'ACROX TECHNOLOGIES CO., LTD.', 'ADEN SERVICES CHINA (GROUP)',
#        'Adva Optical Networking SE', 'Aegon Nederland N.V.',
#        'AFRY (ÅF Pöyry)', 'Å Energi', 'Agility', 'Agropur Cooperative',
#        'Aico',
#        'Airsys Refrigeration Engineering Technology (Beijing) Co., Ltd.',
#        'Aitken Spence PLC', 'AJE GROUP', 'Akamai Technologies INC',
#        'AKDAŞ DÖKÜM A.Ş.', 'Akila',
#        'Albert Bartlett and Sons (Airdrie) Ltd.',
#        'Alchem International Private Limited', 'ALD',
#        'ALE INTERNATIONAL SASU (GROUP)',
#        'Alkaram Towel Industries (Pvt.) Ltd.',
#        'Alliance One Apparel Co.,Ltd', 'Allianz Investment Management SE',
#        'Alltech, Inc.', 'ALPHA INDO NUSA', 'Alpin Çorap San. Ve Tic. A.Ş',
#        'Alun Griffiths (Contractors) Ltd', 'Amalgamated Construction Ltd',
#        'Amazon', 'America Movil, S.A.B. de C.V.', 'Americanas S.A.',
#        'Amey UK plc', 'Ammper Energía S.A.P.I de C.V', 'An Post',
#        'Anabas UK2 Ltd', 'Analog Devices, Inc.', 'Anthem, Inc.',
#        'APERAM S.A.', 'Aqua America', 'Aramex Group', 'Arcelor Mittal',
#        'Archroma International Ltd', 'Armando Alvarez Group',
#        'Armstrong Engineering Limited', 'Arteche', 'Artelia',
#        'Arthur Cox LLP', 'Artistic Fabric Mills (Pvt.) Ltd.',
#        'Artistic Milliners', 'Arvind Limited',
#        'Asahi Europe & International', 'Asda Group Limited',
#        'Asian Apparels ltd', 'Atlas Honda Limited', 'Atomic Austria GmbH',
#        'Atos SE', 'AUGA group, AB', 'Autoliv Inc', 'Aviatur S.A.S.',
#        'Avícola Coliumo', 'Avieco', 'Avison Young (UK) Limited',
#        'Axfood AB', 'AYYILDIZ DOKUMA KUMAS PAZ. SAN VE TIC. A.S.',
#        'B2R Local No.1 Pty Ltd', 'Bachy Soletanche Limited',
#        'Bangladesh Export Import Company Limited',
#        'Bari Textile Mills Pvt. Limited.', 'Bboxx Ltd.',
#        'BekaertDeslee NV', 'BEL S.A.', 'Belfius Bank SA',
#        'Belgotex Floorcoverings (Pty) Ltd', 'BES Engineering Corporation',
#        'Bharti Airtel Limited', 'BHG Group', 'BIAL', 'Bidfood',
#        'Big Yellow Group PLC', 'BioMar Group', 'BKUK Group Ltd',
#        'Block, Inc.', 'Boma Global', 'Bonnier News', 'Boozt',
#        'Boral Limited', 'BOUYGUES CONSTRUCTION',
#        'Braathens Regional Airlines (BRA) AB', 'Branston Ltd',
#        'Brillio LLC', 'British American Tobacco (BAT)',
#        'Buckingham Group Contracting Ltd',
#        'Cancer Research Horizons Limited',
#        'Capella Hotel Group Pte. Ltd.', 'Capitas Finance Limited',
#        'Capri Holdings Limited', 'Carlsberg Group', 'Carrefour',
#        'CARTIER', 'Casa Rica Mercado Gourmet - ALES S.A', 'Cast & Crew',
#        'CCL Industries, Inc.', 'CELSA Group', 'CEMAsys.com AS',
#        'CHALCO Ruimin Co., Ltd.', 'Chime Communications',
#        'China Shengmu Organic Milk Limited', 'CHINALCO-SWA CO.,LTD.',
#        'Chindata Group', 'CIeNET', 'Cikautxo', 'Citrix Systems, Inc.',
#        'City Facilities Management Holdings Ltd (UK)', 'Clarivate, PLC',
#        'Clarke Telecom', 'Classic Fashion Apparel Industry Ltd. Co.',
#        'Clif Bar & Company', 'Clipper Logistics Plc', 'CMA CGM S.A.',
#        'CMPC', 'CNH Industrial N.V.', 'Cobalt Fashion Holding Limited',
#        'Coillte CGA', 'ColliCare Logistics AS', 'ComBio Energia S.A.',
#        'Commercial International Bank Egypt (SAE) CIB',
#        'Communisis Limited', 'Community Services.net Pty Ltd (CSnet)',
#        'Companhia Paranaense de Energia - COPEL',
#        'COMPAÑÍA HULERA TORNEL SA DE CV., MEXICO',
#        'Compass Group Nederland Holding B.V', 'Compass Group UK&I',
#        'Condé Nast', 'Consid AB',
#        'Consolidated Property Services (Australia) Pty Ltd', 'Convoy',
#        'Coolfinity International B.V.', 'Copart UK Ltd', 'Corbion',
#        'Corteva Agriscience', 'Crayon Group Holding ASA',
#        'Crescent Bahuman Limited (CBL)', 'Croda International Plc',
#        'Crowley Maritime Corporation', 'Cultivo Land PBC', 'Currys plc',
#        'CVENT Inc.', 'CWT', 'Cybercom Group AB',
#        "D'decor Home Fabrics Pvt Ltd",
#        'Dairygold Food Ingredients UK Ltd.', 'Dalmia Bharat Limited',
#        'Dassault Systemes', 'Davidson Consulting',
#        'DB Cargo (UK) Limited', 'Delmar International Inc',
#        'Delphi Technologies', 'Delta Display Limited', 'Dentons', 'Dexus',
#        'Diageo Plc', 'Ditrolic Energy Holdings Sdn. Bhd',
#        'DMG MORI AKTIENGESELLSCHAFT', 'DNV AS',
#        'Dongguan NVT Technology Co.,Ltd.', 'Dorada Foods',
#        'Downer EDI Limited', 'Drees & Sommer SE', 'DS Smith', 'DT Global',
#        'Dutch-Bangla Pack Ltd.', 'DWF Group PLC', 'Dyer & Butler',
#        'easyJet plc', 'Eaton', 'EDF Group', 'Edge Environment Pty Ltd',
#        'EFL', 'EIZO Corporation', 'Elecon Engineering Co. Ltd',
#        'Electricity Supply Board (ESB)', 'Element Materials Technology',
#        'Embotelladoras Bolivianas Unidas S.A.', 'Emmi Group',
#        'Empire Company Limited and Sobeys Inc.', 'Emtec Group',
#        'Energia Group', 'ENTAIN PLC', 'Envases Universales de México',
#        'Envision Group', 'EQUANS UK & IRELAND', 'ERI', 'Erith',
#        'Esmaltec S.A.', 'Espresso House', 'Essex Furukawa Magnet Wire',
#        'Euronext', 'Eurostar International Ltd', 'Eurovia UK Ltd',
#        'EVA AIRWAYS CORPORATION', 'Everis Portugal',
#        'Evoqua Water Technologies', 'ExlService Holdings, Inc.',
#        'EXPLEO GROUP', 'Extra Light (Guangzhou) Electrical Co. Ltd.',
#        'Exyte GMBH', 'Familia Torres', 'Farm Frites', 'FashionCube',
#        'Ferrocarrils de la Generalitat de Catalunya',
#        'FGV Holdings Berhad', 'First Greater Western Ltd',
#        'FirstGroup PLC', 'Flexential Corp.', 'Flexport',
#        'Flight Centre Travel Group', 'Flipkart Group', 'FM Logistic',
#        'Foodmark AB', 'Forest Carbon Ltd.', 'Forterra PLC',
#        'FPA Multifamily LLC', 'Frasers Centrepoint Trust',
#        'Frasers Logistics and Commercial Trust Pte Ltd',
#        'Frasers Property Commercial Management Pte Ltd',
#        'Frasers Property Industrial',
#        'Frasers Property Retail Management Pte Ltd',
#        'Frasers Property Singapore (Development& Projects)',
#        'Freeport-McMoRan Inc.', 'FSP Technology Inc.',
#        'Futur Pension Försäkringsaktiebolag (publ)',
#        'Galaxy Surfactants Limited', 'GANT AB', 'Gap Inc.',
#        'GB Railfreight Ltd', 'GCC S.A.B de C.V', 'Geelen Counterflow',
#        'Gefco', 'Gelopar Refrigeração Paranaense Ltda',
#        'GENESIS FASHIONS LIMITED', 'Glanbia Ireland DAC',
#        'GN Store Nord A/S', 'Godrej & Boyce Mfg. Co. Ltd.',
#        'Godrej Consumer Products Limited', 'Godrej Industries',
#        'GOL (GOL Linhas Aéreas S.A.)',
#        'Gold Creek Foods, LLC / Gold Creek Processing, LLC',
#        'Gonvarri Industries', 'Goodman Group',
#        'GoodWay Technology Co.,Ltd.', 'GRAHAM', 'Grayce',
#        'Great British Communications Ltd', 'Greene King Limited',
#        'Greenfish SA', 'GreenFlex', 'GRI Renewable Industries',
#        'Group Fu Plastic Co., LTD', 'Groupe RG', 'Growthpoint Properties',
#        'GRUPO ACOTRAL', 'GRUPO ELECNOR', 'Grupo Ferrer Internacional SA',
#        'Grupo Sesé', 'Grupo SOMA', 'Grupo Televisa, S.A.B.',
#        'GSL – Global Star Logistics', 'GT Incorporated Company',
#        'Guayaki Yerba Mate', 'Gujarat Fluorochemicals Ltd. (GFL)',
#        'Gul Ahmed Textile Mills Limited', 'Gymshark',
#        'H.U. Group Holdings, Inc.', 'Hager SE', 'Haldex',
#        'Halfords Group PLC', 'Hang Seng Bank Limited',
#        'Harmony Gold Mining Company Limited',
#        'Harro Höfliger Verpackungsmaschinen GmbH', 'Hawaiian Electric',
#        'Hayley Group Ltd', 'Hayleys Fabric PLC', 'Heathrow Airport',
#        'Hebei Chengxin Co. Ltd', 'Hela Clothing',
#        'Henan Hengfeng Top Leisure Co.,LTD', 'Henry Schein, Inc.',
#        'Heraeus Precious Metals', 'High Speed Two Ltd.',
#        'Hindalco Industries Limited', 'Hoare Lea LLP',
#        'Hoi Meng Sourcing (Macao Commercial Offshore) Ltd', 'HOK',
#        'Holmen AB', 'Huizhou TCL Mobile Communication Co,Ltd.',
#        'Humanscale', 'HUNG HING METAL MANUFACTORY LIMITED',
#        'Huntapac Produce Ltd', 'Hurtigruten Group', 'Husqvarna AB',
#        'IBERIA, Líneas Aéreas de España, S.A',
#        'Iberostar Hotels and Resorts', 'Icon Construction',
#        'Ideal Modular Homes', 'IGM Resins B.V.', 'Iguá Saneamento S.A.',
#        'Imagination Technologies', 'Indorama Ventures PCL', 'Indra',
#        'Infarm', 'Infrabel n.v.', 'Inghams Group Ltd', 'Ingram Micro',
#        'Inkia Energy Group (Nautilus Energy Holdings LLC)',
#        'innocent drinks', 'Inspired PLC',
#        'Institutional Shareholder Services',
#        'International Automotive Components Group, S.A.',
#        'International Consolidated Airlines Group (IAG)',
#        'Internet Fusion Ltd',
#        'Interplex Precision Technology (S) Pte Ltd', 'InterRent REIT',
#        'Intouch Group, LLC', 'Investa Office Management Pty Limited',
#        'Ipackchem Group', 'IPS-Integrated Project Services', 'Ipsen SA',
#        'ITL Holdings Limited', 'ITP Aero', 'Ivanhoé Cambridge',
#        'IWATSU ELECTRIC CO.,LTD.', 'Jackson Family Wines',
#        'JACKY PERRENOT', 'Jan De Nul Group', 'Japan Airlines Co., Ltd.',
#        'JBS', 'JD Logistics', 'Jiangsu Bono Casting Co., Ltd.',
#        'JIANGSU HONGBANG CHEMICAL TECHNOLOGY CO., LTD',
#        'Jiangsu Pacific Quartz Co., Ltd.', 'JMB Wind Engineering',
#        'John F Hunt Ltd', 'John Sisk & Son', 'Johnson & Johnson',
#        'JSW Cement', 'JSW Energy Limited', 'Jupiter Bach',
#        'K-9 Internacional', 'Kainos Group plc', 'KAO Corporation',
#        'Kayama Kogyo Co.,Ltd.', 'KB Home', 'Kelani Valley Plantations',
#        'Kenya Electricity Generating Company PLC', 'Keolis',
#        'KFC UK & Ireland', 'Kindred Group plc', 'Kiwi Property Group',
#        'Kizilay İçecek', 'KME Germany GmbH',
#        'Korea Agro-Fisheries & Food Trade Corporation', 'KPMG Ireland',
#        'KPMG UK LLP', 'Kumho Tire Co., Inc.', 'Kvadrat A/S',
#        'L&T Technology Services Limited (LTTS)', 'La-Z-Boy Inc',
#        'Lagan Aviation & Infrastructure', 'Lamb Weston / Meijer vof',
#        'Lamb Weston Holdings', 'Landgard Obst & Gemüse GmbH & Co.KG',
#        'Lansinoh Laboratories Inc', 'Lars Partners',
#        'Larsen & Toubro Infotech Ltd.', 'LATAM Airlines Group S.A.',
#        'Lawson,Inc.', 'LEAX Group AB',
#        'Leoch International Technology Limited',
#        'Maersk Contract Logistics Management (Asia) Limited', 'LG Chem',
#        'LG Innotek', 'Liberty Mills Limited',
#        'Lincolnshire Co-operative Limited', 'Linden Foods',
#        'Link Logistics Real Estate', 'Livent', 'LKQ Corporation',
#        'LOYALTEXTILE MILLS LIMITED', 'Lozier Corporation',
#        'LTP Group A/S', 'Lufthansa Group', 'LUKER AGRÍCOLA',
#        'Luxshare Precision Industry Co.,Ltd', 'MAAL Associates, LLC',
#        'MacArthur Green', 'MaCher (USA) Inc.', 'Macintyre Hudson LLP',
#        'Macmillan Publishers, Inc.', 'MG Apparel', 'Maintel Holdings Plc',
#        'Malaysian Resources Corporation Berhad', 'Mambu',
#        'Mammut Sports Group', 'ManpowerGroup Inc.',
#        'Marfrig Global Foods S.A.', 'Marks & Spencer',
#        'Marvell Technology Inc.', 'MASISA', 'Masood Roomi',
#        'Materialise NV',
#        'Mattos Filho, Veiga Filho, Marrey Jr and Quiroga Advogados',
#        'Mayer-network', 'MBH Corporation Plc', 'McCann Worldgroup',
#        'McGinley Support Services (Infrastructure) Limited', 'MCM',
#        'Media6', 'Mediabrands Limited', 'Meggitt PLC', 'Mercado Libre',
#        'Mercedes-Benz Grand Prix Ltd',
#        'MICHEL TRANSPORTEURS ASSOCIES (MTA)', 'Microsoft Corporation',
#        'Midwestern Group Ltd.', 'Milarex', 'Mileway',
#        'MiljöMatematik Malmö AB', 'Millicom International Cellular S.A.',
#        'Mills AS', 'Mintel Group Limited', 'Minto Apartment REIT',
#        'Minto Properties Inc', 'MIZUNO CORPORATION', 'momo.com Inc.',
#        'Movida Participações S.A', 'Moya Holdings Asia Limited',
#        'MS&AD Insurance Group Holdings, Inc.',
#        'MSM MALAYSIA HOLDINGS BERHAD', 'MTR Nordic Group',
#        'Mulberry Group plc', 'Multiplex Construction Europe',
#        'MYTILINEOS S.A.', 'Nahar Industrial Enterprises Limited',
#        "Nando's Australia Pty Ltd", 'National Grid (Group) PLC',
#        'National Windscreens', 'NATS Holdings Limited', 'Natura & Co',
#        'Ndevr Environmental', 'Nechi Group',
#        'Needle Craft for Clothing Industry', 'NEMERA', 'Viaplay Group AB',
#        'Neptuno Pumps', 'NetApp Inc.', 'Netflix', 'Network Rail plc',
#        'Nexii Building Solutions Inc.',
#        'Nice Group Holding Corp., Limited',
#        'Nishat Mills Ltd. (Apparel Division)', 'NKT Cables Group A/S',
#        'NOABRANDS', 'Nolato AB', 'Nomad Foods Ltd.', 'Norican Group',
#        'Normec 1 B.V.', 'Northern Ireland Electricity Networks',
#        'NOS, SPGS, S.A.', 'NOSOPLAS', 'NR Instant Produce Co., Ltd',
#        'NREP', 'NRG Energy Inc', 'Nutrien Ltd.',
#        'Octopus Energy Group Limited', 'Ogier',
#        'ONO PHARMACEUTICAL CO., LTD.', 'Opain S.A', 'Ordina',
#        'Oriental Aromatics Ltd', 'Orluna LED Technologies Limited',
#        'Osborne Infrastructure Limited', 'OTSUKA CORPORATION', 'Ovako AB',
#        'OVO Energy Ltd', 'Pactiv Evergreen Inc.',
#        'Pakistan Cables Limited', 'Pakistan Services Limited',
#        'Palantir Technologies Inc.', 'PALFINGER AG',
#        'Palladium Group Holdings Pty Ltd', 'Panera Bread',
#        'Paramount Global', 'Parker Hannifin Corporation',
#        'Partners in Performance', 'Peak Performance Production AB',
#        'Pennon Group', 'PerkinElmer', 'Perkins & Will UK Ltd.',
#        'Pfizer Inc.',
#        'PH-CH SAS : PIPER-HEIDSIECK, CHARLES HEIDSIECK, RARE CHAMPAGNE',
#        'Pick n Pay', 'Plantasjen Group AS', 'Plenish Drinks',
#        'PNZ-Produkte GmbH', 'Point B', 'Polpaico BSA', 'Prada Group',
#        'Premier Foods PLC', 'Principal Financial Group, Inc.',
#        'Privi Speciality Chemicals Limited', 'Procter & Gamble Company',
#        'Profile Security Services Ltd', 'PT Ecogreen Oleochemicals',
#        'PT INDESSO AROMA', 'PT KAHATEX', 'PT PRIMA SEJATI SEJAHTERA',
#        'Public Power Corporations',
#        'Public Service Enterprise Group Inc. (PSEG)',
#        'Pyxus International, INC', 'Qingdao Hanhe Cable., Ltd.',
#        'Qisda Group', 'Qontigo GmbH', 'Quattro Plant Ltd',
#        'Raymond (PanYu NanSha) Electrical Appliance Development Co., Ltd.',
#        'ReAcción / Alva', 'REDEVCO B.V.',
#        'Regent Electron (Chongqing) Co.,Ltd.', 'Reichle & De-Massari AG',
#        'Reinert Logistic GmbH & Co. KG', 'Reitan Convenience Sweden AB',
#        'Reka Cables Ltd.', 'Reliance Chemical Products Ltd.',
#        'Restaurant Brands International Inc.', 'RETAL', 'Ricardo PLC',
#        'Ricoh Co., Ltd.', 'Ring Automotive Ltd', 'Ringway Jacobs Ltd',
#        'Rogers & Company Limited', 'RONAL AG',
#        'Ross-shire Engineering Limited', 'Royal Vopak',
#        'RSS Infrastructure Ltd', 'RT Knits Ltd', 'S&P Global',
#        'Salom Electric (Xiamen) Co., Ltd.', 'SANDEN Group',
#        'Sapphire Finishing Mills Limited',
#        'Sapphire Textile Mills Limited', 'Sapphire Utility Solutions',
#        'Sarena Textile Industries (Pvt.) Ltd.',
#        'Sasa Polyester Sanayi A.S.', 'SATS Ltd.', 'Saur', 'Savills Plc',
#        'Scanfil Oyj', 'SCM Garments PVT Limited', 'SECOM Co., Ltd.',
#        'SECURECORP PTY LTD', 'SecuriGroup Limited', 'Sekisui House, LTD',
#        'SEMIKRON Elektronik GmbH & Co. KG', 'SES S.A.',
#        'Seven & i Holdings Co., Ltd.',
#        'SHANDONG NHU PHARMACEUTICAL CO., LTD.',
#        'Shenzhen Bromake New Material Co.,Ltd.',
#        'SHINWA CONSTRUCTION CO., LTD', 'SICAL',
#        'Sichuan Yongxiang Co., LTD.',
#        'Sichuan Zhongguang Lightning Protection Technologies Co., Ltd.',
#        'Siddiqsons Limited', 'Sidi Kerir Petrochemicals Co. (SIDPEC)',
#        'Siemens Gamesa Renewable Energy, S.A.', 'Siemon',
#        'Silgan Closures', 'Silgan Plastics', 'Siltronic AG',
#        'Silver Fern Farms Limited', 'Sipsmith',
#        'Skipton Building Society', 'Sky Group', 'SkyPower Global',
#        'Smart Phases Inc. (DBA Novacab)', 'SMEC ANZ', 'Smithfield Foods',
#        'AtkinsRéalis', 'Soil Engineering Geoservices Limited',
#        'South Asia Textiles Limited', 'South East Water',
#        'SPL Powerlines UK Ltd', 'Splunk Inc.',
#        'Squire Patton Boggs UK LLP', 'SSE', 'Stagecoach Group ltd',
#        'Standard Chartered Bank', 'Stantec Inc.', 'STARK Group',
#        'Stena Recycling AB', 'Stonemen Crafts India Pvt. Ltd.',
#        'Storytel AB (publ)', 'Stryhns AS',
#        'Stylers International Limited', 'SUEZ', 'Sulzer Management AG',
#        'SUMIDA CORPORATION', 'SUNREX TECHNOLOGY CORP.',
#        'Suntory Beverage & Food Limited', 'Suntory Holdings Limited',
#        'Sunway Berhad', 'Sunway REIT', 'Super Micro Computer, Inc.',
#        'Sveaskog AB', 'SVOLT Energy Technology',
#        'Switch Mobility Limited', 'Tactus Group',
#        'Tag Worldwide Holdings Ltd (UK)', 'Taiga Apparel (Pvt.) Limited',
#        'TAIWAN PAIHO LIMITED',
#        'Tangshan Dongya Heavy-Industry Equipment Co.,Ltd.',
#        'Tata Consultancy Services Limited', 'TATA GLOBAL BEVERAGES Ltd.',
#        'Taylors Wines', 'TAZO', 'TCE Jeans Co., Ltd',
#        'TCE Vina Denim Joint Stock Company', 'Tchibo GmbH',
#        'TCI Co., Ltd.',
#        'TCL King Electrical Appliance (HuiZhou) CO.,Ltd.',
#        'Teachers Mutual Bank', 'Tech Mahindra',
#        'Teejay India Private Limited', 'Teejay Lanka PLC',
#        'Teejay Lanka Prints Private Limited',
#        'Telehouse Corporation of Europe', 'Telkom SA SOC Limited',
#        'TenneT Holding B.V.', 'The Arnotts Group',
#        'The Berkeley Group Holdings plc',
#        'The British Standards Institution (BSI)', 'The Carey Group Ltd',
#        'The Hongkong & Shanghai Hotels, Limited', 'The Kroger Co.',
#        'The Lux Collective Ltd', 'The Midcounties Co-operative',
#        'The MISSION Group PLC', 'The Schneider Group',
#        'The Southern Co-operative Ltd', 'The Tata Power Company Limited',
#        'thinkstep-anz', 'TIER Mobility SE', 'Tintex Textiles, S.A',
#        'TK Elevator GmbH', 'Tokio Marine Holdings, Inc.',
#        'Tokyo Steel Manufacturing Co.,Ltd.', 'TOPCO SCIENTIFIC CO., LTD.',
#        'TPK Glass Solutions (Xiamen) Inc. Jimei Branch', 'TPXimpact',
#        'TransAlta Corporation', 'Transart Graphics Co., Ltd.',
#        'Translink', 'Transpennine Express', 'Transportes J. Amaral, S.A.',
#        'TravelPerk', 'Trax Apparel (Cambodia) Co., Ltd.', 'Trelleborg AB',
#        'Trench High Voltage Products Ltd., Shenyang',
#        'Trina Solar Co., Ltd.', 'True Corporation Public Company Limited',
#        'TUNG MUNG INTERNATIONAL PTE. LTD', 'Turner & Townsend Ltd',
#        'TVS Supply Chain Solutions Limited', 'Twitter Inc', 'UDR',
#        'UK Greetings Limited', 'Uludağ İçecek', 'Unidas S/A',
#        'Unilever plc', 'Uniserve', 'Unisteel', 'United Airlines, Inc.',
#        'Unity Software Inc', 'Univar Solutions', 'US Apparel & Textiles',
#        'Vakrangee Limited', 'Vale S.A.', 'Valeo', 'SM Industries',
#        'VALORA Sustainability & Innovation', 'Vandemoortele NV',
#        'vdk bank', 'Vereinigte Papierwarenfabriken GmbH', 'VERMEG',
#        'Vestas Wind Systems', 'Vibro Menard Limited', 'Vicinity Centres',
#        'Videndum plc', 'Vidroporto S.A.', 'Viessmann Group',
#        'Viet Nam Samho Company Limited', 'Viña Casa Silva',
#        'VINCI Construction UK Ltd', 'Viridor',
#        'Vital Energi Utilities Limited', 'Vital Human Resources Ltd',
#        'VNET Group Inc.', 'Von Bundit Co., Ltd', 'Votorantim Cimentos',
#        'Wallenius Wilhelmsen', 'Walmart Inc.', 'Waterman Group Plc',
#        'Wealmoor Ltd.', 'Webhelp', 'Weener Plastics Group BV',
#        'Wells & Co.', 'Welspun India Limited', 'Wernsing Feinkost GmbH',
#        'Westfalia Fruit International', 'Weyerhaeuser Company',
#        'Willmott Dixon Holdings Limited', 'Winnebago Industries',
#        'Wizz Air Holdings Plc.', 'Workspace Group PLC',
#        'Worldwide TechService LLC', 'WPP Plc', 'Xerox Corporation',
#        'Xiamen Intretech Inc', 'Yahoo Japan Corporation',
#        'Yarra Valley Water', 'YES Bank', 'Yotrio Group Co., Ltd.',
#        'Yum China Holdings, Inc.', 'Yum! Brands, Inc.',
#        'Zenergi Group Limited', 'Zenobe Energy', 'Zentis GmbH & Co. KG',
#        'ZF Friedrichshafen AG', 'ZND UK LTD', 'ZTO Express (Cayman) Inc.',
#        'Zhejiang Narada Power Source Co., Ltd.', 'Itransition',
#        'Prose Technologies India Pvt Ltd',
#        'Adani Ports and Special Economic Zone Limited',
#        'Adani Energy Solutions Limited'], dtype=object)

# %%
companies_with_removed_targets = sbti_df[sbti_df['Status']=='Removed']['Company Name'].unique()
sbti_df = sbti_df[~sbti_df['Company Name'].isin(companies_with_removed_targets)]

# %% [markdown]
# ## Task Description
#
# SBTi uploading task is about
# 1. Uploading the tenants, which exists are in SBTi, but not in CC'DB.
# 2. Adding targets of this tenants

# %% [markdown]
# ## Find a list of companies TBA
#
# * Company name can be written in different way for example
#   In SBTi dashboard "Cargill, Inc."           ->.       In the platform "Cargill".
# * This section is about find a list of companies to be added to the platform, taking into account the difficutlies of spelling.

# %%
sbti_companies = sbti_df['Company Name'].str.strip().dropna().str.lower()
tenants_companies_corrected = companies_df['Name'].str.strip().dropna().str.lower()

def preprocess_company_name(name):
    #if not isinstance(name, str):
    #  return

    # Remove common suffixes
    suffixes = ['inc', 'llc', 'corp', 'corporation', 'company', 'co', 'limited', 'ltd', '.', ',']
    for suffix in suffixes:
        name = name.replace(suffix, '')
    return name.strip()

# Apply preprocessing to the company names
sbti_companies = sbti_companies.apply(preprocess_company_name)
tenants_companies_corrected = tenants_companies_corrected.apply(preprocess_company_name)

# %%
def find_similar_names_rapidfuzz(list1, list2, threshold=90):
    matches = []
    i = 0
    for name1 in list1:
        if i % 100 == 0:
          print(i)

        i = i + 1
        best_match = process.extractOne(name1, list2, scorer=fuzz.token_sort_ratio)
        if best_match and best_match[1] >= threshold:
            matches.append((name1, best_match[0]))
            print((name1, best_match[0]))
    return matches

# Find similar names
matches_rapidfuzz = find_similar_names_rapidfuzz(sbti_companies, tenants_companies_corrected)
# Out:
# 0
# ('deutsche glasfaser group gmbh', 'deutsche glasfaser group gmbh')
# ('drax group plc', 'drax group plc')
# ('ab inbev', 'ab inbev')
# ('abbvie', 'abbvie')
# ('acbel polytech', 'acbel polytech')
# ('accenture', 'accenture')
# ('archer daniels midland', 'archer daniels midland')
# ('aigle international sa', 'aigle international')
# ('allied sustainability and environmental nsultants group', 'allied sustainability and environmental nsultan')
# 100
# ('api restauration', 'api restauration')
# ('atlassian oration plc', 'atlassian oration plc')
# ('aubay', 'aubay')
# 200
# ('bce', 'bce')
# ('berner', 'berner')
# 300
# ('brenntag se', 'brenntag sa')
# ('bureau veritas', 'bureau veritas')
# 400
# ('chalhoub group', 'chalhoub group')
# ('citrosu agroindustria sa', 'citrosu agroindustria sa')
# ('cnp assurances', 'cnp assurances')
# 500
# ('danone', 'danone')
# ('decathlon', 'decathlon')
# 600
# ('döhler group se', 'döhler group se')
# ('drax group plc', 'drax group plc')
# ('drt (a  of the firmenich group)', 'drt (a  of the firmenich group)')
# ('elab', 'elab')
# 700
# ('eversheds sutherland (international) llp', 'eversheds sutherland (international) llp')
# ('ey', 'ey')
# ('feldmuehle gmbh', 'feldmuehle gmbh')
# 800
# ('geodis', 'gedis')
# 900
# ('graphic packaging international', 'graphic packaging international')
# ('iliad', 'iliad')
# ('groupe seb', 'sel groupe')
# ('havea group', 'havas group')
# 1000
# ('hermès international', 'hermes international')
# ('ingka holding bv (ikea group)', 'ingka holding bv  (ikea group)')
# 1100
# ('jll', 'jll')
# ('johnson matthey plc', 'johnson matthey plc')
# ('jules', 'jules')
# ('kalsec', 'kalsec')
# 1200
# ('kering', 'kering')
# ('kiloutou', 'kiloutou')
# ('lc packaging international bv', 'lc packaging international bv')
# ('levi strauss &', 'levi strauss &')
# 1300
# ('loxam', 'loxam')
# ('magna international', 'mega international')
# 1400
# 1500
# ('nexans', 'nexans')
# ('ntt data oration', 'ntt data oration')
# 1600
# ('outokumpu oyj', 'outokumpu oyj')
# ('panzani', 'panzani')
# ('pepsi', 'pepsi')
# ('pernod ricard', 'pernod ricard')
# ('pfeifer & langen gmbh &  kg', 'pfeifer & langen gmbh &  kg')
# 1700
# 1800
# ('royal swinkels nv', 'royal swinkels')
# ('schneider electric', 'schneider electric se')
# 1900
# ('sopra steria group', 'sopra steria group')
# ('sopra steria group', 'sopra steria group')
# 2000
# ('stmicroelectronics nv', 'stmicroelectronics')
# ('symrise ag', 'symrise ag')
# ('systra', 'systra')
# 2100
# 2200
# ('ubisoft entertainment', 'ubisoft entertainment')
# ('vestiaire llective', 'vestiaire llective')
# 2300
# ('wavestone', 'wavestone')
# ('westn international', 'tn international')
# ('worldline', 'worldline')
# 2400
# ('smcp group', 'groupe smcp')
# ('smcp group', 'groupe smcp')
# ('criteo', 'criteo')
# ('lecta', 'lectra')
# ('renewi', 'renewi')
# 2500
# ('lebronze alloys', 'lebronze alloys')
# ('circet', 'circet')
# 2600
# ('ipm', 'ipm')
# 2700
# ('ame', 'ame')
# 2800
# ('axione', 'axione')
# 2900
# 3000
# ('keolis rennes', 'keolis rennes')
# 3100
# ('prodware', 'prodware')
# ('aaf la providence', 'aaf la providence ii')
# 3200
# ('dorc international', 'arc international')
# ('id logistics', 'id logistics')
# ('fountaine pajot', 'fountaine pajot')
# ('opérative u enseigne', 'operative u enseigne')
# 3300
# ('onepoint', 'onepoint')
# ('nsf international', 'tn international')
# ('vpk group', 'vpk group')
# 3400
# ('in group', 'in groupe')
# ('optimum group bv', 'optimum group bv')
# ('systra', 'systra')
# 3500
# ('delta dore', 'delta dore')
# ('pellini', 'pellini')
# 3600
# ('puratos', 'puratos')
# 3700
# 3800
# 3900
# 4000
# ('gerflor', 'gerflor')
# 4100
# ('france télévisions publicité', 'france télévisions publicité')
# 4200
# ('epsa', 'epsa')
# 4300
# 4400
# ('solutec', 'solutec')
# ('maison johanes boubee', 'maison johanes boubee')
# ('neurones', 'neurones')
# ('swile', 'swile')
# ('ayming', 'ayming')
# 4500
# ('dmax', 'dmax')
# ('elab', 'elab')
# ('elab', 'elab')
# 4600
# ('acbel polytech', 'acbel polytech')
# ('chalhoub group', 'chalhoub group')
# ('chalhoub group', 'chalhoub group')
# ('citrosu agroindustria sa', 'citrosu agroindustria sa')
# ('citrosu agroindustria sa', 'citrosu agroindustria sa')
# ('cloudfm group', 'cloudfm group')
# ('cloudfm group', 'cloudfm group')
# ('cloudfm group', 'cloudfm group')
# ('deutsche glasfaser group gmbh', 'deutsche glasfaser group gmbh')
# ('deutsche glasfaser group gmbh', 'deutsche glasfaser group gmbh')
# ('deutsche glasfaser group gmbh', 'deutsche glasfaser group gmbh')
# ('drax group plc', 'drax group plc')
# ('drax group plc', 'drax group plc')
# ('drax group plc', 'drax group plc')
# ('drax group plc', 'drax group plc')
# ('drt (a  of the firmenich group)', 'drt (a  of the firmenich group)')
# ('drt (a  of the firmenich group)', 'drt (a  of the firmenich group)')
# ('drt (a  of the firmenich group)', 'drt (a  of the firmenich group)')
# ('drt (a  of the firmenich group)', 'drt (a  of the firmenich group)')
# ('drt (a  of the firmenich group)', 'drt (a  of the firmenich group)')
# ('drt (a  of the firmenich group)', 'drt (a  of the firmenich group)')
# 4700
# ('bureau veritas', 'bureau veritas')
# ('bureau veritas', 'bureau veritas')
# 4800
# ('malteries soufflet', 'malteries soufflet')
# ('malteries soufflet', 'malteries soufflet')
# 4900
# ('ab inbev', 'ab inbev')
# ('ab inbev', 'ab inbev')
# ('ab inbev', 'ab inbev')
# ('abbvie', 'abbvie')
# ('abbvie', 'abbvie')
# ('abbvie', 'abbvie')
# ('accenture', 'accenture')
# ('accenture', 'accenture')
# ('accenture', 'accenture')
# ('accenture', 'accenture')
# ('accenture', 'accenture')
# 5000
# 5100
# ('aigle international sa', 'aigle international')
# ('aigle international sa', 'aigle international')
# ('airbus', 'airbus')
# ('airbus', 'airbus')
# ('allied sustainability and environmental nsultants group', 'allied sustainability and environmental nsultan')
# 5200
# ('allied sustainability and environmental nsultants group', 'allied sustainability and environmental nsultan')
# ('allied sustainability and environmental nsultants group', 'allied sustainability and environmental nsultan')
# ('amgen', 'amgen')
# ('amgen', 'amgen')
# ('amgen', 'amgen')
# ('amgen', 'amgen')
# 5300
# 5400
# 5500
# ('atlassian oration plc', 'atlassian oration plc')
# ('atlassian oration plc', 'atlassian oration plc')
# ('atlassian oration plc', 'atlassian oration plc')
# ('atlassian oration plc', 'atlassian oration plc')
# ('atlassian oration plc', 'atlassian oration plc')
# ('atlassian oration plc', 'atlassian oration plc')
# ('atlassian oration plc', 'atlassian oration plc')
# ('aubay', 'aubay')
# ('aubay', 'aubay')
# ('aubay', 'aubay')
# ('avanista group', 'avanista group')
# 5600
# ('ball oration', 'ball oration')
# ('ball oration', 'ball oration')
# 5700
# ('barry callebaut', 'barry callebaut')
# ('bce', 'bce')
# ('bce', 'bce')
# ('bce', 'bce')
# 5800
# 5900
# ('bouygues telem', 'bouygues telem')
# ('bouygues telem', 'bouygues telem')
# 6000
# 6100
# 6200
# ('cargill', 'cargill')
# ('cargill', 'cargill')
# 6300
# 6400
# 6500
# ('lisée group', 'lisee group')
# ('lisée group', 'lisee group')
# 6600
# 6700
# ('danone', 'danone')
# ('danone', 'danone')
# ('danone', 'danone')
# ('danone', 'danone')
# ('danone', 'danone')
# ('danone', 'danone')
# ('danone', 'danone')
# 6800
# ('decathlon', 'decathlon')
# ('decathlon', 'decathlon')
# ('decathlon', 'decathlon')
# ('decathlon', 'decathlon')
# ('decathlon', 'decathlon')
# 6900
# 7000
# 7100
# 7200
# ('enerlis', 'enerlis')
# ('enerlis', 'enerlis')
# ('enerlis', 'enerlis')
# ('engie', 'engie')
# ('engie', 'engie')
# ('engie', 'engie')
# 7300
# ('etivoet', 'etivoet')
# ('eversheds sutherland (international) llp', 'eversheds sutherland (international) llp')
# ('eversheds sutherland (international) llp', 'eversheds sutherland (international) llp')
# 7400
# ('ey', 'ey')
# ('ey', 'ey')
# ('ey', 'ey')
# ('ey', 'ey')
# 7500
# 7600
# 7700
# 7800
# 7900
# ('graphic packaging international', 'graphic packaging international')
# ('graphic packaging international', 'graphic packaging international')
# 8000
# ('groupe seb', 'sel groupe')
# ('groupe seb', 'sel groupe')
# ('groupe seb', 'sel groupe')
# ('iliad', 'iliad')
# ('iliad', 'iliad')
# ('iliad', 'iliad')
# ('iliad', 'iliad')
# ('iliad', 'iliad')
# ('guerlain', 'guerlain')
# ('guerlain', 'guerlain')
# ('guerlain', 'guerlain')
# 8100
# ('havea group', 'havas group')
# ('havea group', 'havas group')
# ('havea group', 'havas group')
# ('havea group', 'havas group')
# 8200
# ('hermès international', 'hermes international')
# ('hermès international', 'hermes international')
# ('hermès international', 'hermes international')
# ('hermès international', 'hermes international')
# 8300
# 8400
# 8500
# ('ingka holding bv (ikea group)', 'ingka holding bv  (ikea group)')
# ('ingka holding bv (ikea group)', 'ingka holding bv  (ikea group)')
# ('ingka holding bv (ikea group)', 'ingka holding bv  (ikea group)')
# ('ingka holding bv (ikea group)', 'ingka holding bv  (ikea group)')
# ('ingka holding bv (ikea group)', 'ingka holding bv  (ikea group)')
# ('ingka holding bv (ikea group)', 'ingka holding bv  (ikea group)')
# 8600
# ('international paper', 'international paper')
# ('international paper', 'international paper')
# ('international paper', 'international paper')
# 8700
# 8800
# ('jll', 'jll')
# ('jll', 'jll')
# ('jll', 'jll')
# ('johnson matthey plc', 'johnson matthey plc')
# ('johnson matthey plc', 'johnson matthey plc')
# ('johnson matthey plc', 'johnson matthey plc')
# ('johnson matthey plc', 'johnson matthey plc')
# 8900
# ('kering', 'kering')
# ('kering', 'kering')
# ('kering', 'kering')
# 9000
# 9100
# ('la banque postale', 'la banque postale')
# ('la banque postale', 'la banque postale')
# ('la banque postale', 'la banque postale')
# ('la banque postale', 'la banque postale')
# ('la banque postale', 'la banque postale')
# ('la banque postale', 'la banque postale')
# ('la banque postale', 'la banque postale')
# ('la banque postale', 'la banque postale')
# ('la banque postale', 'la banque postale')
# 9200
# ('lc packaging international bv', 'lc packaging international bv')
# ('lc packaging international bv', 'lc packaging international bv')
# ('levi strauss &', 'levi strauss &')
# ('levi strauss &', 'levi strauss &')
# ('levi strauss &', 'levi strauss &')
# ('levi strauss &', 'levi strauss &')
# ('levi strauss &', 'levi strauss &')
# 9300
# ('logista', 'logista')
# ('logista', 'logista')
# 9400
# ('louis vuitton malletier', 'louis vuitton malletier')
# ('louis vuitton malletier', 'louis vuitton malletier')
# ('loxam', 'loxam')
# ('loxam', 'loxam')
# ('loxam', 'loxam')
# ('loxam', 'loxam')
# ('loxam', 'loxam')
# ('loxam', 'loxam')
# ('lumen technologies', 'mgen technologies')
# ('lumen technologies', 'mgen technologies')
# ('magna international', 'mega international')
# ('magna international', 'mega international')
# ('magna international', 'mega international')
# ('magna international', 'mega international')
# 9500
# 9600
# 9700
# 9800
# 9900
# ('mowi asa', 'mowi asa')
# ('mowi asa', 'mowi asa')
# ('mowi asa', 'mowi asa')
# ('mowi asa', 'mowi asa')
# 10000
# ("nature's management", "nature's management")
# ("nature's management", "nature's management")
# ("nature's management", "nature's management")
# ("nature's management", "nature's management")
# 10100
# ('nexans', 'nexans')
# ('nexans', 'nexans')
# 10200
# 10300
# ('ntt data oration', 'ntt data oration')
# ('ntt data oration', 'ntt data oration')
# ('ntt data oration', 'ntt data oration')
# ('ntt data oration', 'ntt data oration')
# ('ntt data oration', 'ntt data oration')
# 10400
# ('outokumpu oyj', 'outokumpu oyj')
# 10500
# ('panzani', 'panzani')
# ('panzani', 'panzani')
# ('panzani', 'panzani')
# ('panzani', 'panzani')
# 10600
# ('pepsi', 'pepsi')
# ('pepsi', 'pepsi')
# ('pernod ricard', 'pernod ricard')
# ('pernod ricard', 'pernod ricard')
# ('pernod ricard', 'pernod ricard')
# ('pernod ricard', 'pernod ricard')
# ('pernod ricard', 'pernod ricard')
# ('pernod ricard', 'pernod ricard')
# ('pernod ricard', 'pernod ricard')
# ('pernod ricard', 'pernod ricard')
# 10700
# 10800
# ('psa automobiles sa', 'psa automobiles sa')
# ('psa automobiles sa', 'psa automobiles sa')
# 10900
# 11000
# ('rexel', 'rexel')
# ('rexel', 'rexel')
# ('rexel', 'rexel')
# ('rexel', 'rexel')
# ('rexel', 'rexel')
# ('reynders etiketten nv', 'reynders etiketten nv')
# 11100
# ('royal swinkels nv', 'royal swinkels')
# ('royal swinkels nv', 'royal swinkels')
# ('royal swinkels nv', 'royal swinkels')
# ('royal swinkels nv', 'royal swinkels')
# ('royal swinkels nv', 'royal swinkels')
# ('royal swinkels nv', 'royal swinkels')
# ('royal swinkels nv', 'royal swinkels')
# ('royal swinkels nv', 'royal swinkels')
# ('royal swinkels nv', 'royal swinkels')
# 11200
# ('safran', 'safran')
# ('safran', 'safran')
# ('safran', 'safran')
# 11300
# ('saverglass', 'saverglass')
# ('saverglass', 'saverglass')
# ('saverglass', 'saverglass')
# ('schneider electric', 'schneider electric se')
# ('schneider electric', 'schneider electric se')
# ('schneider electric', 'schneider electric se')
# ('schneider electric', 'schneider electric se')
# ('schneider electric', 'schneider electric se')
# ('schneider electric', 'schneider electric se')
# 11400
# ('see group', 'lisee group')
# ('sharp oration', 'sharp oration')
# ('sharp oration', 'sharp oration')
# 11500
# 11600
# 11700
# ('sodiaal union', 'sodiaal union')
# ('sodiaal union', 'sodiaal union')
# ('soitec', 'soitec')
# ('soitec', 'soitec')
# ('sopra steria group', 'sopra steria group')
# ('sopra steria group', 'sopra steria group')
# ('sopra steria group', 'sopra steria group')
# ('sopra steria group', 'sopra steria group')
# 11800
# ('sopra steria group', 'sopra steria group')
# ('square', 'square')
# ('square', 'square')
# 11900
# ('stmicroelectronics nv', 'stmicroelectronics')
# ('stmicroelectronics nv', 'stmicroelectronics')
# ('stmicroelectronics nv', 'stmicroelectronics')
# 12000
# ('symrise ag', 'symrise ag')
# ('symrise ag', 'symrise ag')
# ('symrise ag', 'symrise ag')
# 12100
# 12200
# 12300
# ('the ca-la', 'the ca-la')
# 12400
# 12500
# 12600
# 12700
# ('ubisoft entertainment', 'ubisoft entertainment')
# ('ubisoft entertainment', 'ubisoft entertainment')
# 12800
# 12900
# ('vestiaire llective', 'vestiaire llective')
# ('vestiaire llective', 'vestiaire llective')
# ('vestiaire llective', 'vestiaire llective')
# 13000
# ('wavestone', 'wavestone')
# ('wavestone', 'wavestone')
# ('wavestone', 'wavestone')
# ('wavestone', 'wavestone')
# ('wavestone', 'wavestone')
# ('westn international', 'tn international')
# ('westn international', 'tn international')
# ('westn international', 'tn international')
# ('westn international', 'tn international')
# ('westn international', 'tn international')
# ('westrock', 'westrock')
# 13100
# ('westrock', 'westrock')
# 13200
# ('worldline', 'worldline')
# ('worldline', 'worldline')
# 13300
# 13400
# ('smcp group', 'groupe smcp')
# ('smcp group', 'groupe smcp')
# ('smcp group', 'groupe smcp')
# 13500
# ('criteo', 'criteo')
# ('criteo', 'criteo')
# ('criteo', 'criteo')
# 13600
# ('itrs group', 'its group')
# ('lebronze alloys', 'lebronze alloys')
# ('lebronze alloys', 'lebronze alloys')
# 13700
# ('circet', 'circet')
# ('circet', 'circet')
# ('circet', 'circet')
# 13800
# 13900
# ('tad inox service bv', 'tad inox service bv')
# 14000
# ('ame', 'ame')
# ('ame', 'ame')
# 14100
# 14200
# 14300
# ('bwd strategic', 'bwd strategic')
# 14400
# 14500
# ('here technologies', 'daher technologies')
# ('here technologies', 'daher technologies')
# ('here technologies', 'daher technologies')
# ('here technologies', 'daher technologies')
# ('schott ag', 'schott ag')
# ('schott ag', 'schott ag')
# ('schott ag', 'schott ag')
# 14600
# 14700
# 14800
# ('keolis rennes', 'keolis rennes')
# ('keolis rennes', 'keolis rennes')
# 14900
# 15000
# 15100
# 15200
# 15300
# 15400
# 15500
# 15600
# ('sogetrel', 'sogetrel')
# ('sogetrel', 'sogetrel')
# 15700
# ('sk international', 'sax international')
# 15800
# ('acbel polytech', 'acbel polytech')
# 15900
# 16000
# 16100
# ('easyvista', 'easyvista')
# 16200
# 16300
# 16400
# 16500
# 16600
# 16700
# ('galeries lafayette', 'galeries lafayette sa')
# ('galeries lafayette', 'galeries lafayette sa')
# ('galeries lafayette', 'galeries lafayette sa')
# ('galeries lafayette', 'galeries lafayette sa')
# 16800
# 16900
# 17000

# %% [markdown]
# filtered_sbti_df contained the companies, TBA

# %%
# Create a DataFrame for the matching companies
matches_rapidfuzz_df = pd.DataFrame(matches_rapidfuzz, columns=['SBTI Company Name', 'Tenant Company Name'])
cleaned_company_names = sbti_df['Company Name'].str.strip().dropna().str.lower()
sbti_df['cleaned_company_name'] = sbti_df['Company Name'].str.strip().str.lower().apply(preprocess_company_name)

# Step 2: Convert the 'SBTI Company Name' column in matches_rapidfuzz_df to lowercase
matches_rapidfuzz_company_names = matches_rapidfuzz_df['SBTI Company Name'].str.lower()

# Step 3: Filter sbti_df based on whether the cleaned company names exist in matches_rapidfuzz_company_names
filtered_sbti_df = sbti_df[~sbti_df['cleaned_company_name'].isin(matches_rapidfuzz_company_names)]

# %%
filtered_sbti_df[sbti_df['Company Name'] == 'PepsiCo, Inc.']
# Out:
# /var/folders/73/qg89nk6105d6084yrk56sfg00000gn/T/ipykernel_22088/711860501.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_sbti_df[sbti_df['Company Name'] == 'PepsiCo, Inc.']
# Empty DataFrame
# Columns: [Company Name, ISIN, LEI, Location, Region, Sector, Organization Type, Action, Commitment Type, Commitment Deadline, Status, Reason for commitment extension or removal, Full target language, Company Temperature Alignment, Target, Target Wording, Scope, Target Value, Type, Sub-type, Target Classification, Base Year, Target Year, Year Type, Date Published, cleaned_company_name]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# ## Map Countries

# %%
sbti_countries = filtered_sbti_df['Location'].unique()
cc_countries = countries_df.Name

# %%
countries_map_df = pd.DataFrame({
    'sbti': sbti_countries,
    'cc': sbti_countries
})

# %%
not_matching_countries = set(sbti_countries) - set(cc_countries)
not_matching_countries
# Out:
# {'Bosnia-Herzegovina',
#  'Czechia',
#  'Hong Kong, China',
#  'Korea, Republic of',
#  'Myanmar',
#  'Philippines',
#  'Russian Federation',
#  'Taiwan, Province of China',
#  'Tanzania, United Republic of',
#  'Türkiye',
#  'United States of America',
#  'Viet Nam'}

# %%
countries_map_df[countries_map_df.sbti == 'Czechia']
# Out:
#        sbti       cc
# 45  Czechia  Czechia

# %%
countries_map_df.loc[countries_map_df['sbti'] == 'Czechia', 'cc'] = 'Czech Republic'
countries_map_df.loc[countries_map_df['sbti'] == 'Bosnia-Herzegovina', 'cc'] = 'Bosnia and Herzegovina'
countries_map_df.loc[countries_map_df['sbti'] == 'Hong Kong, China', 'cc'] = 'Hong Kong'
countries_map_df.loc[countries_map_df['sbti'] == 'Korea, Republic of', 'cc'] = 'South Korea'
# Remove Macau <-- doesn't exist on our platform
countries_map_df.loc[countries_map_df['sbti'] == 'Macau, China', 'cc'] = None
countries_map_df.loc[countries_map_df['sbti'] == 'Myanmar', 'cc'] = 'Myanmar (Burma)'
# Remove Philippines
countries_map_df.loc[countries_map_df['sbti'] == 'Philippines', 'cc'] = None
countries_map_df.loc[countries_map_df['sbti'] == 'Russian Federation', 'cc'] = 'Russia'
countries_map_df.loc[countries_map_df['sbti'] == 'Taiwan, Province of China', 'cc'] = 'Taiwan'
countries_map_df.loc[countries_map_df['sbti'] == 'Tanzania, United Republic of', 'cc'] = 'Tanzania'
countries_map_df.loc[countries_map_df['sbti'] == 'Türkiye', 'cc'] = 'Turkey'
countries_map_df.loc[countries_map_df['sbti'] == 'United States of America', 'cc'] = 'United States'
countries_map_df.loc[countries_map_df['sbti'] == 'Viet Nam', 'cc'] = 'Vietnam'

# %%
filtered_sbti_df.columns
# Out:
# Index(['Company Name', 'ISIN', 'LEI', 'Location', 'Region', 'Sector',
#        'Organization Type', 'Action', 'Commitment Type', 'Commitment Deadline',
#        'Status', 'Reason for commitment extension or removal',
#        'Full target language', 'Company Temperature Alignment', 'Target',
#        'Target Wording', 'Scope', 'Target Value', 'Type', 'Sub-type',
#        'Target Classification', 'Base Year', 'Target Year', 'Year Type',
#        'Date Published', 'cleaned_company_name'],
#       dtype='object')

# %%
mapping = dict(zip(countries_map_df['sbti'], countries_map_df['cc']))
filtered_sbti_df['Location'] = filtered_sbti_df['Location'].map(mapping)
filtered_sbti_df = filtered_sbti_df.dropna(subset=['Location'])
# Out:
# /var/folders/73/qg89nk6105d6084yrk56sfg00000gn/T/ipykernel_22088/3035417504.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_sbti_df['Location'] = filtered_sbti_df['Location'].map(mapping)

# %%
sbti_countries = filtered_sbti_df['Location'].unique()
cc_countries = countries_df.Name
not_matching_countries = set(sbti_countries) - set(cc_countries)
not_matching_countries
# Out:
# set()

# %% [markdown]
# ## Map Industries

# %%
sbti_industries = filtered_sbti_df['Sector'].unique()
cc_industries = industries_df.Name

# %%
set(sbti_industries) - set(cc_industries)
# Out:
# {'Electric Utilities and Independent Power Producers and Energy Traders (including Fossil, Alternative and Nuclear Energy)',
#  'Gas Utilities',
#  nan}

# %%
industries_map_df = pd.DataFrame({
    'sbti': sbti_industries,
    'cc': sbti_industries
})

# %%
industries_map_df.loc[industries_map_df['sbti'] == 'Electric Utilities and Independent Power Producers and Energy Traders (including Fossil, Alternative and Nuclear Energy)', 'cc'] = 'Electric Utilities and Independent Power Producers and Energy Traders (including fossil, alternative and nuclear energy)'
industries_map_df.loc[industries_map_df['sbti'] == 'Gas Utilities', 'cc'] = None
industries_map_df.loc[industries_map_df['sbti'] == 'nan', 'cc'] = None

# %%
mapping = dict(zip(industries_map_df['sbti'], industries_map_df['cc']))
filtered_sbti_df['Sector'] = filtered_sbti_df['Sector'].map(mapping)
filtered_sbti_df = filtered_sbti_df.dropna(subset=['Sector'])

# %%
sbti_industries = filtered_sbti_df['Sector'].unique()
cc_industries = industries_df.Name
set(sbti_industries) - set(cc_industries)
# Out:
# set()

# %% [markdown]
# ## Add Country and Industry Ids

# %%
countries_df.head()
# Out:
#    Id            Name TwoCharCode ThreeCharCode          Name.1 TwoCharCode.1  \
# 0   1     Afghanistan          AF           AFG     Afghanistan            AF
# 1   2   Aland Islands          AX           ALA   Aland Islands            AX
# 2   3         Albania          AL           ALB         Albania            AL
# 3   4         Algeria          DZ           DZA         Algeria            DZ
# 4   5  American Samoa          AS           ASM  American Samoa            AS
#
#   ThreeCharCode.1
# 0             AFG
# 1             ALA
# 2             ALB
# 3             DZA
# 4             ASM

# %%
mapping = dict(zip(countries_df.Name, countries_df.Id))
filtered_sbti_df['CountryId'] = filtered_sbti_df['Location'].map(mapping)
filtered_sbti_df.CountryId.isna().any()
# Out:
# np.False_

# %%
mapping = dict(zip(industries_df.Name, industries_df.Id))
filtered_sbti_df['IndustryId'] = filtered_sbti_df['Sector'].map(mapping)
filtered_sbti_df.IndustryId.isna().any()
# Out:
# np.False_

# %% [markdown]
# ## Save the results
#
# We are interested only in CompanyName, CuntryId, SectorId

# %%
result_df = filtered_sbti_df[[
    'Company Name',
    'CountryId',
    'IndustryId'
]].drop_duplicates(subset=['Company Name'])

# %%
result_df.to_csv('companies_to_upload.csv', index=False)
